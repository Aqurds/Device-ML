# %% [markdown]
# # Crisp DM Method

# %% [markdown]
# ### 1. Business Understanding

# %% [markdown]
# -  Increase the sellable devices for a manufacturing company.
#
# Context is: if the early prediction of which devices may fail can be calculated, rework can be done to save these devices before they need to be discarded. End goal is increasing Yield (= sellable devices).

# %% [markdown]
# ### 2. Data Understanding (This is a data from a company, ABC Technologies)

# %% [markdown]
# - columns: date(YYYY-MM-DD format), device id, failure(non-failure is 0, failure is 1), atrributes1-9 (manufacturing data)

# %% [markdown]
# ### 3. Data Prep

# %% [markdown]
# - data preprocessing:
#
# fill NA: there was no NA in this data set, if there is => I fill it with mean/median depending on the case.
#
# check if there is any outliers: there was no outliers detected, I looked it by plotting each and every variable by failure
#
# - feature scaling:
# if there is any categorical data, turn them into numerical using label encoding, and/or one hot encoding.
#
# - normalization/standardization
#
# if a model will be used which assumes normalized data, or a model which will be sensitive to standardization => standardize the data. In this problem, I standardized my independent variables and also used the non-standard variables for my data

# %% [markdown]
# ### 4. Modelling

# %% [markdown]
# As the outcome is failure with 0 and 1 values, this will be a binary classification problem.
#
# - Linear SVC
# - Decision Tree Classifier
# - Random Forest Classifier
# - Logistic Regression
# - KNN
# - SVC with Kernal trick ('rbf')

# %% [markdown]
# ### 5. Evaluation

# %% [markdown]
# - Accuracy ( this does not help us as we have an imbalanced data set)
# - Log Loss
# - AUROC score
# - Confusuion matrix

# %% [markdown]
# ### 6. Deployment

# %% [markdown]
# By using the machine learning model above, early detection of potential device failures were made, as a result %3 increase on the number of sellable devices have achieved. This was to address the saving of the damaged devices by proper manufacturing rework.

# %% [markdown]
# # Roadmap

# %% [markdown]
# 1. Data Preprocessing and visualization
# 2. Machine Learning Models
# 3. Evaluation of Models
# 4. Conclusion

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import Perceptron
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC



#score
from sklearn.metrics import accuracy_score
from sklearn.metrics import log_loss
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # 1. Data Preprocessing and Visualization

# %%
# Load the training data

data = pd.read_csv('device_failure_worksample.csv',sep=',')
data.head()
# Out:
#     date    device  attribute1  attribute2  attribute3  attribute4  \
# 0  15001  S1F01085   215630672          56           0          52
# 1  15001  S1F0166B    61370680           0           3           0
# 2  15001  S1F01E6Y   173295968           0           0           0
# 3  15001  S1F01JE0    79694024           0           0           0
# 4  15001  S1F01R2B   135970480           0           0           0
#
#    attribute5  attribute6  attribute7  attribute8  attribute9  failure
# 0           6      407438           0           0           7        0
# 1           6      403174           0           0           0        0
# 2          12      237394           0           0           0        0
# 3           6      410186           0           0           0        0
# 4          15      313173           0           0           3        0

# %%
# Check for class imbalance

data.groupby('failure').size()/len(data.failure)
# Out:
# failure
# 0    0.999149
# 1    0.000851
# dtype: float64

# %%
data['failure'].value_counts().plot(kind='bar', logy=True);
# Nearly 99% of the data belongs to class '0' there is clearly a class imbalance issue
# While running the model on full data, I will track performance metrics in addition to the accuracy
#(such as log loss and AUROC scores)

# %%
#Let us see the column values
print(data.columns.values)
# Out:
# ['date' 'device' 'attribute1' 'attribute2' 'attribute3' 'attribute4'
#  'attribute5' 'attribute6' 'attribute7' 'attribute8' 'attribute9'
#  'failure']

# %%
data.info()
print('_'*40)
# we look at the overall data info  and see we do not have any null values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124494 entries, 0 to 124493
# Data columns (total 12 columns):
# date          124494 non-null int64
# device        124494 non-null object
# attribute1    124494 non-null int64
# attribute2    124494 non-null int64
# attribute3    124494 non-null int64
# attribute4    124494 non-null int64
# attribute5    124494 non-null int64
# attribute6    124494 non-null int64
# attribute7    124494 non-null int64
# attribute8    124494 non-null int64
# attribute9    124494 non-null int64
# failure       124494 non-null int64
# dtypes: int64(11), object(1)
# memory usage: 10.9+ MB
# ________________________________________

# %%
data.describe()b
# Out:
#                 date    attribute1     attribute2     attribute3  \
# count  124494.000000  1.244940e+05  124494.000000  124494.000000
# mean    15106.222798  1.223868e+08     159.484762       9.940455
# std        78.412061  7.045960e+07    2179.657730     185.747321
# min     15001.000000  0.000000e+00       0.000000       0.000000
# 25%     15040.000000  6.127675e+07       0.000000       0.000000
# 50%     15086.000000  1.227957e+08       0.000000       0.000000
# 75%     15168.000000  1.833084e+08       0.000000       0.000000
# max     15306.000000  2.441405e+08   64968.000000   24929.000000
#
#           attribute4     attribute5     attribute6     attribute7  \
# count  124494.000000  124494.000000  124494.000000  124494.000000
# mean        1.741120      14.222693  260172.858025       0.292528
# std        22.908507      15.943021   99151.009852       7.436924
# min         0.000000       1.000000       8.000000       0.000000
# 25%         0.000000       8.000000  221452.000000       0.000000
# 50%         0.000000      10.000000  249799.500000       0.000000
# 75%         0.000000      12.000000  310266.000000       0.000000
# max      1666.000000      98.000000  689161.000000     832.000000
#
#           attribute8     attribute9        failure
# count  124494.000000  124494.000000  124494.000000
# mean        0.292528      12.451524       0.000851
# std         7.436924     191.425623       0.029167
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000
# max       832.000000   18701.000000       1.000000

# %% [markdown]
# # From upper description of the dataset, it's clear that atrribtue1, attribute5 & attribute6 has equal distributed data. The others features attribute is not equaly distributed. You will see in first quartile(25%), second quartile(50%) & third quartile(75%) representing 0. The more analysis is below at cell no:11

# %%
#Dropping the device variable as it is categorical
data_for_view = data
data_for_view.drop(['device'], axis=1, inplace=True)

# %%
sns.pairplot(data_for_view)

# %% [markdown]
# Above graph shows me tha attr7 and attr8 are linearly correlated, I want to double check that, yes - I will only take one of them as they are identical

# %%
from scipy.stats import linregress

linregress(data['attribute7'],data['attribute8'])
# Out:
# LinregressResult(slope=1.0, intercept=0.0, rvalue=1.0, pvalue=0.0, stderr=0.0)

# %%
plt.scatter(data['attribute7'],data['attribute8'], color = 'red')

# %%
columns = ['date', 'attribute1', 'attribute2', 'attribute3', 'attribute4', 'attribute5', 'attribute6',  'attribute8', 'attribute9']

x = data[columns]

y = data['failure']

# %%
plt.boxplot(x['attribute1'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1208a50>,
#   <matplotlib.lines.Line2D at 0x1208c50>],
#  'caps': [<matplotlib.lines.Line2D at 0x1208eb0>,
#   <matplotlib.lines.Line2D at 0x1208fb0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x12087d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1211410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1211610>],
#  'means': []}

# %% [markdown]
# # ploting each feature attribute in box plot it shows outliers. specifically in attribute2, attribute4, attribute9 outliers in dominating the features.

# %%
plt.boxplot(x['attribute2'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb32930>,
#   <matplotlib.lines.Line2D at 0xb328f0>],
#  'caps': [<matplotlib.lines.Line2D at 0xb32110>,
#   <matplotlib.lines.Line2D at 0xb3e490>],
#  'boxes': [<matplotlib.lines.Line2D at 0xb32430>],
#  'medians': [<matplotlib.lines.Line2D at 0xb3e050>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb3ef90>],
#  'means': []}

# %%
plt.boxplot(x['attribute3'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xeeeab0>,
#   <matplotlib.lines.Line2D at 0xeeecb0>],
#  'caps': [<matplotlib.lines.Line2D at 0xeeef10>,
#   <matplotlib.lines.Line2D at 0xeeeff0>],
#  'boxes': [<matplotlib.lines.Line2D at 0xeee830>],
#  'medians': [<matplotlib.lines.Line2D at 0xef5470>],
#  'fliers': [<matplotlib.lines.Line2D at 0xef5670>],
#  'means': []}

# %%
plt.boxplot(x['attribute4'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xf28610>,
#   <matplotlib.lines.Line2D at 0xf28810>],
#  'caps': [<matplotlib.lines.Line2D at 0xf28a70>,
#   <matplotlib.lines.Line2D at 0xf28d30>],
#  'boxes': [<matplotlib.lines.Line2D at 0xf28390>],
#  'medians': [<matplotlib.lines.Line2D at 0xf28fb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0xf2f1d0>],
#  'means': []}

# %%
plt.boxplot(x['attribute5'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xf61510>,
#   <matplotlib.lines.Line2D at 0xf61710>],
#  'caps': [<matplotlib.lines.Line2D at 0xf61970>,
#   <matplotlib.lines.Line2D at 0xf61c30>],
#  'boxes': [<matplotlib.lines.Line2D at 0xf61290>],
#  'medians': [<matplotlib.lines.Line2D at 0xf61eb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0xf61f50>],
#  'means': []}

# %%
plt.boxplot(x['attribute6'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xf93e90>,
#   <matplotlib.lines.Line2D at 0xf9b270>],
#  'caps': [<matplotlib.lines.Line2D at 0xf9b4d0>,
#   <matplotlib.lines.Line2D at 0xf9b790>],
#  'boxes': [<matplotlib.lines.Line2D at 0xf93dd0>],
#  'medians': [<matplotlib.lines.Line2D at 0xf9ba10>],
#  'fliers': [<matplotlib.lines.Line2D at 0xf9bc10>],
#  'means': []}

# %%
plt.boxplot(x['attribute8'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x117f7f0>,
#   <matplotlib.lines.Line2D at 0x117f9f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x117fc50>,
#   <matplotlib.lines.Line2D at 0x117ff10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x117f570>],
#  'medians': [<matplotlib.lines.Line2D at 0x117ffb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11843b0>],
#  'means': []}

# %%
plt.boxplot(x['attribute9'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11aef10>,
#   <matplotlib.lines.Line2D at 0x11b72f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x11b7550>,
#   <matplotlib.lines.Line2D at 0x11b7810>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11aee50>],
#  'medians': [<matplotlib.lines.Line2D at 0x11b7a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11b7c90>],
#  'means': []}

# %% [markdown]
# # I have checked each attribute feature with lower analysis. It shows 118110 data is equal to 0 out of 124494 data in 'attribute2'.

# %%
x[x['attribute2'] == 0].count()
# Out:
# date          118110
# attribute1    118110
# attribute2    118110
# attribute3    118110
# attribute4    118110
# attribute5    118110
# attribute6    118110
# attribute8    118110
# attribute9    118110
# dtype: int64

# %%
x['attribute2'].mean()
# Out:
# 159.4847623178627

# %%
x[x['attribute2'] > x['attribute2'].mean()].count()
# Out:
# date          4443
# attribute1    4443
# attribute2    4443
# attribute3    4443
# attribute4    4443
# attribute5    4443
# attribute6    4443
# attribute8    4443
# attribute9    4443
# dtype: int64

# %% [markdown]
# # Cell:57: With above analysis we see, there are only 4443 features above mean value out of 124494 features

# %%
x[x['attribute2'] == 0].count()
# Out:
# date          118110
# attribute1    118110
# attribute2    118110
# attribute3    118110
# attribute4    118110
# attribute5    118110
# attribute6    118110
# attribute8    118110
# attribute9    118110
# dtype: int64

# %% [markdown]
# # Cell:59: In 'attribute2' the mean, median, q1 & q3 is 0, max is 64968, mean is 159.485

# %%
from numpy import percentile
column_data = data['attribute2']
quartiles = percentile(column_data, [25, 50, 75])
data_min, data_max, data_mean = column_data.min(), column_data.max(), column_data.mean()

print('Min: %.3f' % data_min)
print('Q1: %.3f' % quartiles[0])
print('Median: %.3f' % quartiles[1])
print('Q3: %.3f' % quartiles[2])
print('Max: %.3f' % data_max)
print('Mean: %.3f' % data_mean)
# Out:
# Min: 0.000
# Q1: 0.000
# Median: 0.000
# Q3: 0.000
# Max: 64968.000
# Mean: 159.485

# %% [markdown]
# # Cell:71: If the difference between a data point and the mean is greater then 1.5 * Iqf, then the data should be considered as outliers. so here are 4443 outliers in this feature.

# %%
Iqr = quartiles[2] - quartiles[0]
print(1.5 * Iqr)

# as the 1.5 * Iqr is 0.0, then any data greater then the mean value is outliers in this feature. 

x[x['attribute2'] > 159.485].count()
# Out:
# 0.0
# date          4443
# attribute1    4443
# attribute2    4443
# attribute3    4443
# attribute4    4443
# attribute5    4443
# attribute6    4443
# attribute8    4443
# attribute9    4443
# dtype: int64

# %%
# Lets see the relation between the variables and the response (failure)
sns.pairplot(data, x_vars=columns, y_vars='failure', kind='scatter');

# %%
# Using custom generic function, which would fit and predict our model
def fit_predict(clf, x_train, y_train, X_test, y_test):
    """
    @ Arguements
        clf: A object of sklearn classifiers
        X_train: Training set data
        y_train: Training set labels
        X_test: Test set data
        y_test: Test set labels
    
    @ Returns
        None
    """
    clf.fit(x_train, y_train)
    
    train_pred = clf.predict(x_train)
    
    # broadcasting model accuracy in this format isn't standard practice
    #print("Training Accuracy:", sum(y_train == train_pred)/len(train_pred))
    
    print("Training Accuracy: ", deci_to_percents(clf.score(x_train, y_train)), "%")
    print("Log Loss Train:", log_loss(y_train, train_pred))
    print("AUROC Score Train:", roc_auc_score(y_train, train_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_train, train_pred))
    

    

    test_pred = clf.predict(x_test)
    
    # broadcasting model accuracy in this format isn't standard practice
    #print("\nTest Accuracy:", sum(y_test == test_pred)/len(test_pred))
    
    print("Test Accuracy: ", deci_to_percents(clf.score(x_test, y_test)), "%")
    print("Log Loss Test:", log_loss(y_test, test_pred))
    print("AUROC Score Test:", roc_auc_score(y_test, test_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, test_pred))
    

    
# making decimal to percents to better visual
def deci_to_percents(deci):
    whole_decimal = deci * 100
    return '%.4f'%(whole_decimal)

# %%
# Split into the Training set and Test set
# This code isn't valid----from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, stratify=y)

print ("Training Data Set Dimensions=", x_train.shape, "Training True Class labels dimensions=", y_train.shape)
print ("Test Data Set Dimensions=", x_test.shape, "Test True Class labels dimensions=", y_test.shape)
# Out:
# Training Data Set Dimensions= (108036, 9) Training True Class labels dimensions= (108036,)
# Test Data Set Dimensions= (6856, 9) Test True Class labels dimensions= (6856,)

# %%
#Feature scaling for optimal performance
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)
# Out:
# c:\program files (x86)\python36-32\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# c:\program files (x86)\python36-32\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#
# c:\program files (x86)\python36-32\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   import sys

# %% [markdown]
# # 2. ML Models and 3. Evaluations

# %% [markdown]
# ### Linear SVC

# %%
print("--------------------------Linear SVC -standardized x------------------------")

#with standard values 
clf = LinearSVC(class_weight='balanced')
fit_predict(clf, x_train_std, y_train, x_test_std, y_test)
print("--------------------------Linear SVC -no standardized x------------------------")

#without standard values
clf = LinearSVC(class_weight='balanced')
fit_predict(clf, x_train, y_train, x_test, y_test)
# Out:
# --------------------------Linear SVC -standardized x------------------------
# c:\program files (x86)\python36-32\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Training Accuracy:  99.7492 %
# Log Loss Train: 0.08663942683992994
# AUROC Score Train: 0.5990227952686619
# Confusion Matrix:
#  [[107750    211]
#  [    60     15]]
# Test Accuracy:  0.1313 %
# Log Loss Test: 34.49423524205921
# AUROC Score Test: 0.5
# Confusion Matrix:
#  [[   0 6847]
#  [   0    9]]
# --------------------------Linear SVC -no standardized x------------------------
# c:\program files (x86)\python36-32\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Training Accuracy:  99.9306 %
# Log Loss Train: 0.02397726896236818
# AUROC Score Train: 0.5
# Confusion Matrix:
#  [[107961      0]
#  [    75      0]]
# Test Accuracy:  99.8687 %
# Log Loss Test: 0.04533970063509378
# AUROC Score Test: 0.5
# Confusion Matrix:
#  [[6847    0]
#  [   9    0]]

# %% [markdown]
# # Decision Tree Classifier

# %%
print("----------------------Decision Tree Classifier - standardize x-----------------")

#with standard values 
clf = DecisionTreeClassifier(class_weight='balanced')
fit_predict(clf, x_train_std, y_train, x_test_std, y_test)

print("----------------------Decision Tree Classifier - no standardize x-----------------")
#without standard values
clf = DecisionTreeClassifier(class_weight='balanced')
fit_predict(clf, x_train, y_train, x_test, y_test)
# Out:
# ----------------------Decision Tree Classifier - standardize x-----------------
# Training Accuracy:  100.0000 %
# Log Loss Train: 9.99200722162641e-16
# AUROC Score Train: 1.0
# Confusion Matrix:
#  [[107961      0]
#  [     0     75]]
# Test Accuracy:  99.8687 %
# Log Loss Test: 0.04533970063509378
# AUROC Score Test: 0.5
# Confusion Matrix:
#  [[6847    0]
#  [   9    0]]
# ----------------------Decision Tree Classifier - no standardize x-----------------
# Training Accuracy:  100.0000 %
# Log Loss Train: 9.99200722162641e-16
# AUROC Score Train: 1.0
# Confusion Matrix:
#  [[107961      0]
#  [     0     75]]
# Test Accuracy:  99.8396 %
# Log Loss Test: 0.05541542291990734
# AUROC Score Test: 0.49985395063531474
# Confusion Matrix:
#  [[6845    2]
#  [   9    0]]

# %% [markdown]
# ### Random Forest Classifier

# %%
print("--------------------Random Forest Classifier -standardized x-------------------")

#with standard values 
clf = RandomForestClassifier(class_weight='balanced')
fit_predict(clf, x_train_std, y_train, x_test_std, y_test)

print("--------------------Random Forest Classifier - no standardized x-------------------")

#without standard values
clf = RandomForestClassifier(class_weight='balanced')
fit_predict(clf, x_train, y_train, x_test, y_test)
# Out:
# --------------------Random Forest Classifier -standardized x-------------------
# c:\program files (x86)\python36-32\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Training Accuracy:  99.9796 %
# Log Loss Train: 0.007033332228962042
# AUROC Score Train: 0.8533333333333333
# Confusion Matrix:
#  [[107961      0]
#  [    22     53]]
# Test Accuracy:  99.8687 %
# Log Loss Test: 0.04533970063509378
# AUROC Score Test: 0.5
# Confusion Matrix:
#  [[6847    0]
#  [   9    0]]
# --------------------Random Forest Classifier - no standardized x-------------------
# c:\program files (x86)\python36-32\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Training Accuracy:  99.9806 %
# Log Loss Train: 0.00671363530946381
# AUROC Score Train: 0.86
# Confusion Matrix:
#  [[107961      0]
#  [    21     54]]
# Test Accuracy:  99.8541 %
# Log Loss Test: 0.05037756177750056
# AUROC Score Test: 0.49992697531765734
# Confusion Matrix:
#  [[6846    1]
#  [   9    0]]

# %% [markdown]
# ### Logistics Regression

# %%
print("--------------------Logistic Regression -standardized x-------------------")

#with standard values 
clf = LogisticRegression(class_weight='balanced')
fit_predict(clf, x_train_std, y_train, x_test_std, y_test)

print("--------------------Logistic Regression -no standardized x-------------------")

#without standard values
clf = LogisticRegression(class_weight='balanced')
fit_predict(clf, x_train, y_train, x_test, y_test)
# Out:
# --------------------Logistic Regression -standardized x-------------------
# c:\program files (x86)\python36-32\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Training Accuracy:  96.1874 %
# Log Loss Train: 1.3168618527688636
# AUROC Score Train: 0.7610764998471671
# Confusion Matrix:
#  [[103875   4086]
#  [    33     42]]
# Test Accuracy:  99.8687 %
# Log Loss Test: 0.04533970063509378
# AUROC Score Test: 0.5
# Confusion Matrix:
#  [[6847    0]
#  [   9    0]]
# --------------------Logistic Regression -no standardized x-------------------
# c:\program files (x86)\python36-32\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Training Accuracy:  96.0337 %
# Log Loss Train: 1.3699327774081136
# AUROC Score Train: 0.7669697390724428
# Confusion Matrix:
#  [[103708   4253]
#  [    32     43]]
# Test Accuracy:  95.8139 %
# Log Loss Test: 1.4458654481063675
# AUROC Score Test: 0.6461467309283871
# Confusion Matrix:
#  [[6566  281]
#  [   6    3]]

# %% [markdown]
# ### KNN

# %%
print("--------------------KNN -standardized x-------------------")

#with standard values 
clf = KNeighborsClassifier(n_neighbors=2, metric='minkowski')
fit_predict(clf, x_train_std, y_train, x_test_std, y_test)

print("--------------------KNN -no standardized x-------------------")

#without standard values
clf = KNeighborsClassifier(n_neighbors=2, metric='minkowski')
fit_predict(clf, x_train, y_train, x_test, y_test)
# Out:
# --------------------KNN -standardized x-------------------
# Training Accuracy:  99.9334 %
# Log Loss Train: 0.023018178203873495
# AUROC Score Train: 0.52
# Confusion Matrix:
#  [[107961      0]
#  [    72      3]]
# Test Accuracy:  99.8687 %
# Log Loss Test: 0.04533970063509378
# AUROC Score Test: 0.5
# Confusion Matrix:
#  [[6847    0]
#  [   9    0]]
# --------------------KNN -no standardized x-------------------
# Training Accuracy:  99.9324 %
# Log Loss Train: 0.023337875123371724
# AUROC Score Train: 0.5133333333333333
# Confusion Matrix:
#  [[107961      0]
#  [    73      2]]
# Test Accuracy:  99.8687 %
# Log Loss Test: 0.04533970063509378
# AUROC Score Test: 0.5
# Confusion Matrix:
#  [[6847    0]
#  [   9    0]]

# %% [markdown]
# ### SVC

# %%
print("--------------------SVC -standardized x-------------------")

#with standard values 
clf = SVC(kernel = 'rbf')
fit_predict(clf, x_train_std, y_train, x_test_std, y_test)
# Out:
# --------------------SVC -standardized x-------------------
# Training Accuracy:  99.9352 %
# Log Loss Train: 0.022378784364877034
# AUROC Score Train: 0.5333333333333333
# Confusion Matrix:
#  [[107961      0]
#  [    70      5]]
# Test Accuracy:  99.8687 %
# Log Loss Test: 0.04533970063509378
# AUROC Score Test: 0.5
# Confusion Matrix:
#  [[6847    0]
#  [   9    0]]

# %%
# This is 'no standardized x' version of plotting except SVC

model_board = ['Linear SVC','Decision Tree Classifier','Random Forest Classifier','Logistics Regression','KNN','SVC']
training_score = [99.9306, 100.0000, 99.9806, 96.0337, 99.9324, 99.9352]
testing_score = [99.8687, 99.8396, 99.8541, 95.8139, 99.8687, 99.8687 ]

 
# data to plot
number_of_models = len(model_board)



ind = np.arange(number_of_models) 
width = 0.25   
# plot first score
plt.bar(ind, training_score, width, label='Traing Score')
#plot second score beside first one with postion first+width, so they don't overlap
plt.bar(ind + width, testing_score, width,
    label='Testing Score')

plt.ylabel('Scores')
plt.title('Scores by Models')
# set xticks witih vertical position
plt.xticks(ind +width/2 , model_board,  rotation='vertical')
# legend set outside of the plot
plt.legend(bbox_to_anchor=(1.4, .6))
plt.show()

# %% [markdown]
# # 4. Conclusion

# %% [markdown]
# First of all, our classes are highly imbalanced.  We have alot more data for failure = 0.
#
# Based on the ML algorithms I ran, I can see that in general, algorithms give similar accuracy. With imbalanced class, using accuracy alone would not be an optimal way.
#
# So, to overcome this, I have added Binary-cross-entropy loss and AUROC Score to accuracy.
# After evaluating on different models, we can see that loss value and AUROC Score is different in all algorithms. It will be wise to choose the algorithm with higher AUROC Score.
#
# We can see that Logistic classifier give AUROC value of around 0.70, SVC gives AUROC values around 0.5 on test set. This is because after correctly classifying the example, SVC does not optimize it. Also, we can see. better AUROC score with standardized X test and X train values. On the other hand logistic regression pushes the probabilities to higher even after correctly classifying, resulting to better AUROC scores. So, in this case Logistic classifier leads to better generalization.
#
# Decision tree train AUROC score and test AUROC scores are quite far from each other. We can explain this issue as overfitting.  Random forest is a better choice but the Auroc score is still lover than teh logistic regression. As it is not general enough, my choice would be logistic regression for this type of problem.

# %% [markdown]
# # Observation from Omar

# %% [markdown]
# As you have mentioned above, this is highly imbalance data. About 99% of data belongs to a single classifier (0). For this, all models in this program giving ridiculously high accuracy in prediction.
#
# If the data is from real life then the end goal is highly predictable.
#
# ** I have changed hyperparameter in the model and those give the same result which is very unlikely!
# Suppose in KNN models the n_neighbors factor 2 gives the result exactly like 5, but the decision boundary with this KNN model shouldn't be the same with two different factors. It's surprising! This is because again for the imbalanced data
#
# ** I wrote a tiny function to output the prediction from decimal to percents
# ** I wrote the scoring output in standard mode
# ** I plotted the score in a plot with models so the total scores of all the models can be seen in a place to evaluate
#
# If you see the score plot, then it's highly predictable that the dataset is not balanced. Either the dataset doesn't contain the influential parameter or this dataset doesn't need to evaluate with any ML model
